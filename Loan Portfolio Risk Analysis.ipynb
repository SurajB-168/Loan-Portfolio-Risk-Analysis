# %%
# Import pandas and load the data

import pandas as pd

# Load the cleaned loan applications data directly from the Excel file
df = pd.read_excel(r"C:\Users\suraj\OneDrive\Desktop\Projects\Cap_Project_5\Cleaned dataset\loan_applications_cleaned.xlsx")

# %%
# Look at the first few rows
df.head()
# Out:
#   Applicant_ID  Applicant_Name  Gender   Age Marital_Status Branch_ID  \
# 0     LN000001    Rajesh Patel    Male  45.0         Single     BR015
# 1     LN000002   Krishna Patel    Male  32.0         Single     BR017
# 2     LN000003  Aditya Chauhan    Male  24.0         Single     BR003
# 3     LN000004       Neha Iyer  Female   NaN         Single     BR001
# 4     LN000005   Reyansh Mehta    Male  30.0         Single     BR016
#
#   Employment_Type  Annual_Income_INR  Credit_Score  Existing_Loans_Count  ...  \
# 0   Self-Employed           528100.0         733.0                     0  ...
# 1        Salaried           780600.0         653.0                     0  ...
# 2        Salaried           442500.0         807.0                     2  ...
# 3  Business Owner           290300.0         779.0                     0  ...
# 4        Salaried           527900.0         701.0                     0  ...
#
#    Interest_Rate_Percent EMI_Monthly_INR  Debt_to_Income_Ratio  \
# ...

# %%
# Check the shape of the data (rows, columns)
df.shape

print(f"The dataset has {df.shape[0]} rows and {df.shape[1]} columns")
# Out:
# The dataset has 5500 rows and 24 columns

# %%
# Check column names and data types

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5500 entries, 0 to 5499
# Data columns (total 24 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Applicant_ID              5500 non-null   object
#  1   Applicant_Name            5500 non-null   object
#  2   Gender                    5500 non-null   object
#  3   Age                       5363 non-null   float64
#  4   Marital_Status            5500 non-null   object
#  5   Branch_ID                 5500 non-null   object
#  6   Employment_Type           5500 non-null   object
#  7   Annual_Income_INR         5390 non-null   float64
#  8   Credit_Score              5418 non-null   float64
#  9   Existing_Loans_Count      5500 non-null   int64
#  10  Existing_EMI_Monthly_INR  5500 non-null   float64
#  11  Loan_Purpose              5500 non-null   object
#  12  Loan_Amount_INR           5500 non-null   int64
# ...

# %%
# Summary statistics for numeric columns

df.describe()
# Out:
#                Age  Annual_Income_INR  Credit_Score  Existing_Loans_Count  \
# count  5363.000000       5.390000e+03   5418.000000           5500.000000
# mean     36.102182       5.018543e+05    677.319860              0.802000
# min      21.000000       9.000000e+04    333.000000              0.000000
# 25%      29.000000       2.964250e+05    615.000000              0.000000
# 50%      36.000000       4.356500e+05    677.000000              1.000000
# 75%      43.000000       6.179000e+05    742.000000              1.000000
# max      65.000000       4.369800e+06    900.000000              6.000000
# std       9.501369       3.184834e+05     94.038573              0.886276
#
#        Existing_EMI_Monthly_INR  Loan_Amount_INR  Loan_Tenure_Months  \
# count               5500.000000     5.500000e+03         5500.000000
# mean                2927.845035     7.910793e+05           82.831636
# min                    0.000000     2.500000e+04            6.000000
# ...

# %%
# Check for missing (null) values in each column

df.isnull().sum()
# Out:
# Applicant_ID                   0
# Applicant_Name                 0
# Gender                         0
# Age                          137
# Marital_Status                 0
# Branch_ID                      0
# Employment_Type                0
# Annual_Income_INR            110
# Credit_Score                  82
# Existing_Loans_Count           0
# Existing_EMI_Monthly_INR       0
# Loan_Purpose                   0
# Loan_Amount_INR                0
# Loan_Tenure_Months             0
# Interest_Rate_Percent          0
# EMI_Monthly_INR                0
# Debt_to_Income_Ratio           0
# Collateral_Value_INR           0
# Late_Payments_Past_Count       0
# Application_Date               0
# Loan_Status                    0
# Default_Flag                   0
# Default_Date                4751
# Days_Past_Due                  0
# dtype: int64
